# %%
import numpy as np
import math 
import matplotlib as plt
import pandas as pds
import seaborn as sbn
import sklearn as skl

# %%
pds.set_option('display.max_colwidth', None)

# %%
lancer les lignes du dessus

# %%
wowbgs = pds.read_csv("Dataset/wowbgs.csv", delimiter=',')

wowbgs.head
# Out:
# <bound method NDFrame.head of      Battleground  Code   Faction         Class  KB  D  HK      DD      HD  \
# 0              WG   WG1     Horde        Hunter   1  3  14   48155    6641
# 1              WG   WG1     Horde  Death Knight   1  3  12   27025    7106
# 2              WG   WG1  Alliance       Paladin   0  1  19     824   93879
# 3              WG   WG1  Alliance       Paladin   1  2  25    7046   98599
# 4              WG   WG1  Alliance         Rogue   2  3  23   65483   19629
# ...           ...   ...       ...           ...  .. ..  ..     ...     ...
# 3721           WG  WG35  Alliance         Druid  18  1  52  123000   49511
# 3722           WG  WG35  Alliance          Monk   0  4  33   13087    9057
# 3723           WG  WG35     Horde        Hunter   2  5  28   57365    6837
# 3724           WG  WG35  Alliance  Death Knight   2  5  41   44997   40934
# 3725           WG  WG35  Alliance          Monk   6  5  44   85443  106000
#
#       Honor  Win  Lose   Rol  BE
# ...

# %% [markdown]
# # Test de correlation entre differents champs

# %%
plt.scatter(wowbgs['DD'],wowbgs['Class'])

# %%
plt.scatter(wowbgs['Honor'],wowbgs['DD'])

# %%
plt.pyplot.scatter(wowbgs['DD'],wowbgs['Honor'],wowbgs['Class'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'sqrt'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-fa2c104b9b23> in <module>
# ----> 1 plt.pyplot.scatter(wowbgs['DD'],wowbgs['Honor'],wowbgs['Class'])
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %% [markdown]
# evaluation sur une colonne qui contient du String impossible

# %%
y = wowbgs['Honor']
X = wowbgs[['DD','Class']]

# %% [markdown]
# mes conaissances actuelles en analyse de données avec python et en wowbgs ne me permette pas de trouver de correlation entre les differents champs ( mise a part celle de DD en fonction de Class )

# %% [markdown]
#  # Nouvelle Dataset

# %%
wowdemo = pds.read_csv("Dataset/wow_demo.csv", delimiter=',')

wowdemo.head(20)
# Out:
#                      Timestamp  Gender Sexuality       Age  \
# 0   2017/07/24 10:19:56 PM AST  Female    Bi/Pan  18 to 30
# 1   2017/07/24 10:25:34 PM AST   Other       Gay  18 to 30
# 2   2017/07/24 10:27:56 PM AST  Female    Bi/Pan  18 to 30
# 3   2017/07/24 10:46:20 PM AST    Male       Gay  18 to 30
# 4   2017/07/24 10:56:33 PM AST    Male  Straight  18 to 30
# 5   2017/07/24 11:45:42 PM AST  Female    Bi/Pan  18 to 30
# 6   2017/07/25 12:00:19 AM AST    Male  Straight  18 to 30
# 7   2017/07/25 12:03:50 AM AST  Female    Bi/Pan  18 to 30
# 8    2017/07/25 3:10:39 AM AST   Other    Bi/Pan  18 to 30
# 9    2017/07/25 7:16:40 AM AST  Female       Gay  31 to 42
# 10   2017/07/25 9:36:56 AM AST    Male       Gay  18 to 30
# 11   2017/07/25 7:34:07 PM AST    Male  Straight  31 to 42
# 12   2017/07/25 9:48:45 PM AST    Male  Straight  43 to 55
# 13   2017/07/25 9:59:51 PM AST    Male  Straight  31 to 42
# 14  2017/07/25 11:06:20 PM AST  Female    Bi/Pan  18 to 30
# ...

# %%
plt.pyplot.scatter(wowdemo['Main'],wowdemo['Gender'])

# %%
plt.pyplot.scatter(wowdemo['Role'],wowdemo['Gender'])

# %%
plt.pyplot.scatter(wowdemo['Max'],wowdemo['Gender'])
