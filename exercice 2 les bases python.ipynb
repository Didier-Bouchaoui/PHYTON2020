# %%
l2 = [x for x in range(10) if x%2==0]

# %%
l2
# Out:
# [0, 2, 4, 6, 8]

# %%
sum(l2)
# Out:
# 20

# %%
len(l2)
# Out:
# 5

# %% [markdown]
# # Exercice

# %% [markdown]
# 1.1

# %%
t1 = [x for x in range (5)]
sum(t1)
# Out:
# 10

# %% [markdown]
# 1.2

# %%
t2 = [x for x in range (5)]

# %%
t3 = [sum(t2),sum(t1)]

# %%
t3
# Out:
# [10, 10]

# %%
t2
# Out:
# [0, 1, 2, 3, 4]

# %%
for x in t2 :
        R = x*t1[x]
        print(R)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
t5 = [input() for in range (5)]
# Out:
#   File "<ipython-input-9-ae826de01c3d>", line 1
#     t5 = [input() for int x in range (5)]
#                           ^
# SyntaxError: invalid syntax

# %%
print(t5)
# Out:
# ['1', '2', '3', '4', '5']

# %%
sum(t5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8d428b16e471> in <module>
# ----> 1 sum(t5)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print a
